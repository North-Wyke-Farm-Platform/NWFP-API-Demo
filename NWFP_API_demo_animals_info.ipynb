# %%
import requests
from google.colab import userdata

# API and login URLs
api_url = "https://api-nwfp.rothamsted.ac.uk/"
login_url = f"{api_url}/api/auth/v1/login/"

# Login credentials
payload = {
    "email": userdata.get("API_EMAIL"),
    "password": userdata.get("API_PASSWORD")
}


# Make the POST request to the login endpoint
response = requests.post(login_url, json=payload)

# Check if the request was successful
if response.status_code == 200:
    response_data = response.json()
    print("Login successful!")
    token = response_data.get("access")
    headers = {"Authorization": f"Bearer {token}"}
    print(f"Bearer {token}")
else:
    print("Login failed!")
    print(f"Status code: {response.status_code}")
    print(f"Response: {response.text}")
# Out:
# Login successful!
# Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNzU4MTM2MDg2LCJpYXQiOjE3NTc0MTYwODYsImp0aSI6ImIxYWIzM2VmZmQwNjRjM2FiNzlkOGI5MGMwOGRiZjc4IiwidXNlcl9pZCI6Mzh9.s0T3b03r8dP-sn57J0AlTmy7hPZ2PBcUuk_5NFLJIb8

# %%
# Catchemnets #
from google.colab import userdata
	
import pandas as pd
from IPython.display import display, HTML

api_url = "https://api-nwfp.rothamsted.ac.uk/"
endpoint = "api/animals/v1/LivestockPerformance/"
api_url = f"{api_url}/{endpoint}"
params = {
    "animalId": 5802,
    "from_date": "2010-11-02",
    "to_date": "2010-12-02"
}
response = requests.get(api_url, headers=headers, params=params)

if response.status_code == 200:
    data = response.json()
    df = pd.DataFrame(data)

else:
    print("Failed to access protected endpoint.")
    print("Status code:", response.status_code)
    print("Response:", response.text)





df = pd.json_normalize(data)
# Set display options
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)


from IPython.display import display, HTML

# Set the scrollable container with max height and overflow
scroll_style = """
<div style="max-height: 400px; overflow-y: scroll;">
    {table}
</div>
"""

# Convert DataFrame to HTML with styling classes
html_table = df.to_html(classes='table table-striped table-bordered', max_rows=None, max_cols=None)

# Display the scrollable table
display(HTML(scroll_style.format(table=html_table)))
# Out:
# <div style="max-height: 400px; overflow-y: scroll;">
#     <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>animalId</th>
#       <th>fromDate</th>
#       <th>weightOnFromDate</th>
#       <th>toDate</th>
#       <th>weightOnToDate</th>
#       <th>weightDifferenceFromTo</th>
#       <th>dateSold</th>
#       <th>finalWeight</th>
#       <th>weightDifferenceFromDateSold</th>
#       <th>weightDifferenceToSold</th>
#       <th>conditionScore</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5802</td>
#       <td>2010-10-25T00:00:00</td>
#       <td>383.0</td>
#       <td>2011-10-18T00:00:00</td>
#       <td>618.0</td>
#       <td>235.0</td>
#       <td>2011-10-18T00:00:00</td>
#       <td>618.0</td>
#       <td>235.0</td>
#       <td>0.0</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
## Animal Locations #

# Base URL
base_url = "https://api-nwfp.rothamsted.ac.uk"


endpoint = "api/animals/v2/Animals-Locations/"

# Combine base URL and endpoint
api_url = f"{base_url}/{endpoint}"

params = {
    "animalId": 5802,
}
response = requests.get(api_url, headers=headers, params=params)

#response = requests.get(api_url, headers=headers)

# Check the response
if response.status_code == 200:
    print("Success!")
    data = response.json()
    df = pd.DataFrame(data)

    # Set the scrollable container with max height and overflow
    scroll_style = """
    <div style="max-height: 400px; overflow-y: scroll;">
        {table}
    </div>
    """
    
    # Convert DataFrame to HTML with styling classes
    html_table = df.to_html(classes='table table-striped table-bordered', max_rows=None, max_cols=None)
    
    # Display the scrollable table
    display(HTML(scroll_style.format(table=html_table)))



else:
    print(f"Failed to access endpoint. Status code: {response.status_code}")
    print("Response:", response.text)
# Out:
# Success!
#     <div style="max-height: 400px; overflow-y: scroll;">
#         <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>officialtag</th>
#       <th>breed</th>
#       <th>dateofbirth</th>
#       <th>grazingyear</th>
#       <th>endgrazingyear</th>
#       <th>gender</th>
#       <th>farmletid</th>
#       <th>birthlittersize</th>
#       <th>rearinglittersize</th>
#       <th>animalcategoryid</th>
#       <th>breedinganimal</th>
#       <th>locations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4834</td>
#       <td>UK 362735 501044</td>
#       <td>HEX</td>
#       <td>2010-02-20T00:00:00</td>
#       <td>2011</td>
#       <td>2011</td>
#       <td>M</td>
#       <td>1</td>
#       <td>None</td>
#       <td>None</td>
#       <td>2</td>
#       <td>False</td>
# ...

# %%
## Catchemnets #

endpoint = "api/catchments/v1/Catchments/"

# Combine base URL and endpoint
api_url = f"{base_url}/{endpoint}"


response = requests.get(api_url, headers=headers, params=params)

#response = requests.get(api_url, headers=headers)

# Check the response
if response.status_code == 200:
    print("Success!")
    data = response.json()
    df = pd.DataFrame(data)

    # Set the scrollable container with max height and overflow
    scroll_style = """
    <div style="max-height: 400px; overflow-y: scroll;">
        {table}
    </div>
    """
    
    # Convert DataFrame to HTML with styling classes
    html_table = df.to_html(classes='table table-striped table-bordered', max_rows=None, max_cols=None)
    
    # Display the scrollable table
    display(HTML(scroll_style.format(table=html_table)))



else:
    print(f"Failed to access endpoint. Status code: {response.status_code}")
    print("Response:", response.text)
# Out:
# Success!
#     <div style="max-height: 400px; overflow-y: scroll;">
#         <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>catchment_id</th>
#       <th>catchment_name</th>
#       <th>displayname</th>
#       <th>offcatchment</th>
#       <th>validfrom</th>
#       <th>validuntil</th>
#       <th>hydrologicalcatchmentarea</th>
#       <th>fencedcatchmentarea</th>
#       <th>farmlet_id_pre_2013</th>
#       <th>farmlet_id</th>
#       <th>farmlet_name</th>
#       <th>field_name</th>
#       <th>boundary</th>
#       <th>farmlet_name_pre_2013</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1</td>
#       <td>Catchment 1</td>
#       <td>False</td>
#       <td>None</td>
#       <td>None</td>
#       <td>5.002812</td>
#       <td>4.807064</td>
#       <td>1</td>
#       <td>1</td>
#       <td>Red</td>
# ...
