# %% [markdown]
# ## Login

# %%
import requests
# Define the API endpoint and payload
url = "http://127.0.0.1:8000/api/auth/v1/login/"
payload = {
    "email": "hazem.nureldin@rothamsted.ac.uk",
    "password": "api"
}

# Make the POST request
response = requests.post(url, data=payload)

# Check the response
if response.status_code == 200:
    response_data = response.json()
    print("Login successful!")
    token = response_data.get("access")
    headers = {"Authorization": f"Bearer {token}"}
    key = (f"Bearer {token}")
    print(key)
else:
    print("Failed to login. Status code:", response.status_code)
    print("Response:", response.text)
# Out:
# Login successful!
# Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNzMwMzU5MDI4LCJpYXQiOjE3Mjk2MzkwMjgsImp0aSI6ImVlNTU3OGUxZjM2YTRjNzBiNjZiZjZiNzI1ZDgwNTNjIiwidXNlcl9pZCI6Mzh9.9_kbmI5SDKeOA9rxoyNU_6LFk1siqDtAWG6cJ8OtP1A

# %%
pip install folium
# Out:
# ...
#
# ...

# %% [markdown]
# # Catchments

# %%
# Catchemnets #
import folium
import numpy as np
import json
from pandas import json_normalize
import pandas as pd
#from IPython.display import display, HTML


# Define the API endpoint and parameters
api_url = "http://localhost:8000/api/catchments/v1/getCatchments/"
params = {
    #"catchments": "catchment 5,met,catchment 6",

}
headers = {
    "Authorization": key,
    "Cache-Control": "no-cache"
}

# Make the GET request
response = requests.get(api_url, headers=headers, params=params)
#response =  requests.get(api_url , headers=headers)
# Check the response
if response.status_code == 200:
    print("API request successful!")
    data = response.json()
#    print(data)
#    df=pd.json_normalizepd(data)
    # Convert the data to a DataFrame

    df = json_normalize(data)    
    print(df)
    

else:
    print("Failed to login. Status code:", response.status_code)
    print("Response:", response.text)

boundary_data = df['boundary']
print(boundary_data)
# Convert to numpy array for easier manipulation
boundary_array = np.array(boundary_data)
print(boundary_array)

# Create a map centered around the first point
m = folium.Map(location=boundary_data[0], zoom_start=15)

# Add the shape to the map
folium.Polygon(locations=boundary_data, color='blue', weight=2.5, opacity=1).add_to(m)

# Save the map to an HTML file
m

# Calculate the center point
#center_point = np.mean(boundary_array, axis=0)

print("Center point of the shape:", center_point)
# Calculate the center of the boundary


# Print the center point
#print(f"Center Point: {center_point}")

# Create the map
#m = folium.Map(location=center, zoom_start=16)

#
# Out:
# API request successful!
#     catchment_id       catchment_name                       displayname  \
# 0              1                    1                       Catchment 1
# 1              2                    2                       Catchment 2
# 2              3                    3                       Catchment 3
# 3              4                    4     Catchment 4 After  2013/08/13
# 4              5                    5                       Catchment 5
# 5              6                    6                       Catchment 6
# 6              7                    7                       Catchment 7
# 7              8                    8                       Catchment 8
# 8              9                    9                       Catchment 9
# 9             10                   10                      Catchment 10
# 10            11                   11                      Catchment 11
# 11            12                   12                      Catchment 12
# ...

# %%
def calculate_center_point(shape):
    shape_array = np.array(shape)
    center_point = np.mean(shape_array, axis=0)
    return center_point

# %%
pip install folium

# %% [markdown]
# # Sample use of Data from the Catchment API

# %%
# Given boundary data with multiple shapes
boundary_data = [    
 list([[[50.76861725506967, -3.8978254743202], [50.76858548266415, -3.8978836763806157], [50.768588980991865, -3.8978875536026862], [50.76859344791575, -3.897895465155102], [50.76863459961521, -3.897968400988475], [50.7686352286791, -3.8979882134174204], [50.768701567495896, -3.898104250679239], [50.76881233096128, -3.8982916440098734], [50.76883832389126, -3.8983346888289816], [50.768970772498335, -3.898559402924036], [50.76898750065749, -3.8985873402281754], [50.769152049373474, -3.8988621461697335], [50.7692979536385, -3.8991021212653436], [50.769319645044845, -3.899138129859125], [50.76932190343706, -3.899141877578586], [50.769325018456584, -3.8991467024110307], [50.76943186052887, -3.898913790828658], [50.769443994490075, -3.898887338653026], [50.7695652560015, -3.898620743765491], [50.769705424873905, -3.898297847175229], [50.769826980960545, -3.8980072672258075], [50.76989906201669, -3.897837120628026], [50.769956792912296, -3.8977008462381377], [50.77004973860875, -3.89746474760841], [50.77005703625639, -3.897445215760797], [50.770054766238275, -3.8974289131592172], [50.77005086925135, -3.8974044875658365], [50.77003892430304, -3.897312381648817], [50.77003474981012, -3.897280191218954], [50.769972033604176, -3.897124353188815], [50.769912534434866, -3.8970090802370123], [50.76988275472087, -3.8969513859231597], [50.769782906369244, -3.8967843936005124], [50.769630264915804, -3.896540983739442], [50.76948565965347, -3.8963735042579515], [50.769473377694055, -3.8963623591982355], [50.769398223587245, -3.8962941604801244], [50.76932587264264, -3.896279561368658], [50.76929103949385, -3.8963341214522416], [50.76921105599689, -3.8965119146360507], [50.76909827462225, -3.896762318111257], [50.76901416541142, -3.8969487756032777], [50.76892772716377, -3.897140394110579], [50.76877313824929, -3.897483045212539], [50.76861725506967, -3.8978254743202]]])

]

# Create a map centered around the first point of the first shape
m = folium.Map(location=boundary_data[0][0][0], zoom_start=15)

# Add each shape to the map
for shape in boundary_data:
    folium.Polygon(locations=shape[0], color='Red', weight=2.5, opacity=1).add_to(m)

# Save the map to an HTML file
m.save('map.html')

print("Map with the shapes has been saved to 'map.html'.")


# Calculate the center point for each shape
center_points = []
for shape in boundary_data:
    center_points.append(calculate_center_point(shape[0]))

print("Center points for each shape:", center_points)

# Adding catchment information as a popup
catchment_info = """
<b>Catchment ID:</b> 2<br>
<b>Catchment Name:</b> 2<br>
<b>Display Name:</b> Catchment 2<br>
<b>Off Catchment:</b> False<br>
<b>Valid From:</b> None<br>
<b>Valid Until:</b> None<br>
<b>Hydrological Catchment Area:</b> 6.792114<br>
<b>Fenced Catchment Area:</b> 6.653351<br>
<b>Farmlet ID Pre-2013:</b> 1<br>
<b>Farmlet ID:</b> 1<br>
<b>Farmlet Name:</b> Red<br>
<b>Field Name:</b> Great Field
"""

popup = folium.Popup(catchment_info, max_width=300)
marker = folium.Marker(location=center_points[0], popup=popup)
marker.add_to(m)
# Adding catchment information as a popup
catchment_info = """
<b>Catchment ID:</b> 2<br>
<b>Catchment Name:</b> 2<br>
<b>Display Name:</b> Catchment 2<br>
<b>Off Catchment:</b> False<br>
<b>Valid From:</b> None<br>
<b>Valid Until:</b> None<br>
<b>Hydrological Catchment Area:</b> 6.792114<br>
<b>Fenced Catchment Area:</b> 6.653351<br>
<b>Farmlet ID Pre-2013:</b> 1<br>
<b>Farmlet ID:</b> 1<br>
<b>Farmlet Name:</b> Red<br>
<b>Field Name:</b> Great Field
"""
i=0
popup = folium.Popup(catchment_info, max_width=300)
for shape in boundary_data:
    folium.Polygon(locations=shape[0], color='Red', weight=2.5, opacity=1).add_to(m)
    marker = folium.Marker(location=center_points[i], popup=popup,color='red', weight=2.5, opacity=1)
    i=(i+1)        
    marker.add_to(m)
    if i>6 :
            exit()

m
# Out:
# Map with the shapes has been saved to 'map.html'.
# Center points for each shape: [array([50.77477343, -3.90580215]), array([50.77349132, -3.90608428]), array([50.77311949, -3.90337849]), array([50.77356277, -3.90198925]), array([50.76287257, -3.89882525]), array([50.76693531, -3.89726524]), array([50.76786107, -3.89893566]), array([50.76833345, -3.89701033]), array([50.76933986, -3.89768986])]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
# ...

# %%
import folium

# Given boundary data with multiple shapes
boundary_data = [
    list([[[50.77427795093604, -3.9049063691089145], [50.77427783761033, -3.904912921708103], [50.77428038052557, -3.904917023504595], [50.774378377941616, -3.9050751107031374], [50.774496834339516, -3.905265850564547], [50.77458239352984, -3.905404326294615], [50.7746207439709, -3.9056232649571143]]]),
    list([[[50.774673622729836, -3.9059275753907627], [50.77471006028736, -3.906140784787681], [50.774718957421044, -3.9061928459654496], [50.77471828754091, -3.9066374278686453], [50.77471600221327, -3.9069836360842487], [50.77471764964531, -3.907334351738996], [50.77478855137548, -3.907741204320814], [50.774791012824494, -3.907739724419571], [50.774797107170684, -3.9077287075452887], [50.774853531122744, -3.907626689229005]]]),
    list([[[50.77517192191931, -3.905395035257982], [50.775070730328935, -3.9052987199689255], [50.77481188317648, -3.9051251833956258], [50.774727501639575, -3.9050733771156274], [50.77465260572501, -3.9050273947556775], [50.77448872969137, -3.904937707546992], [50.77428643905131, -3.9048440923040744], [50.774285198249004, -3.904855251389165], [50.774285021212336, -3.904856839879585], [50.7742809169315, -3.9048846791210963], [50.774278553301656, -3.9049007101143047], [50.77427795093604, -3.9049063691089145]]]
        )
]

# Create a map centered around the first point of the first shape
m = folium.Map(location=boundary_data[0][0][0], zoom_start=15)

# Add each shape to the map
for shape in boundary_data:
    folium.Polygon(locations=shape[0], color='blue', weight=2.5, opacity=1).add_to(m)

# Save the map to an HTML file
m.save('map.html')

print("Map with the shapes has been saved to 'map.html'.")
# Out:
# Map with the shapes has been saved to 'map.html'.
